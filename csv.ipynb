# %%
import csv
import os
#x_center, y_center, width, height
# Left Eye,173,184,4134.jpg,600,600
# Right Eye,228,184,4134.jpg,600,600
# Mouth Center,75,310,4134.jpg,600,600

# Left Eye,173,184,4134.jpg,600,600
# # Right Eye,228,184,4134.jpg,600,600
# # Mouth Center,75,310,4134.jpg,600,600

# 0 0.472932 0.409774 0.105263 0.145865 #4134.txt




#4134.jpg 
0.472932 0.409774 0.105263 0.145865 173,184 228,184 75,310

# %%
for file in os.listdir("./primate_image/train/labels/")

# %%
# for file in os.listdir("./primate_image/train/labels/"):
#     filepath = os.path.join("./primate_image/train/labels",file)
#     with open(filepath) as f:
#         lines = f.readlines()
#         for line in lines:
#             line = line.split(" ")
            
#             print(line[1]*600, line[2]*600, line[3]*600, line[4]*600)
#             with open('GORILLA LABEL 1.csv', 'r') as csv_file:
#                 reader = csv.reader(csv_file, delimiter = ',')   
#                 with open('new_names.csv', 'w') as new_file:
#                     csv_writer = csv.writer(new_file, delimiter=',')
#                     for row  in reader:
                        
#                         text = [row[3], line[1]*600, line[2]*600, line[3]*600, line[4]*600]
#                         csv_writer.writerow(text)
                        
file = open("./allcsv.csv")
file1 = open("MyFile.txt","a")
for f in os.listdir("./primate_image/train/labels/"):
    with open(os.path.join("./primate_image/train/labels/", f),'r') as f:
        lines = f.readlines()
        for line1 in lines:
            print(line1)
#             line = line.split(" ")
            newf = str(f)
            temp1 = os.path.basename(newf)
    #         print(temp1)
            temp = temp1.split("'")
            temp2 = temp[0].split(".") #labels.txt ['2240', 'txt']
    #         print(temp2[0]) #2240
            csvreader = csv.reader(file)
            for line in csvreader:
                tempfile = str(line[3]).split(".") #csv
    #             print(temp2)
    #             abcd = 
                if tempfile[0] == temp2[0]:
                    writetofile = [tempfile[0],'\n', line1[1], line1[2], line1[3], line1[4], line[1], line[2]]
                    print(str(writetofile))
                    file1.write(str(writetofile))
#                 file1.write("kriti")
 # 0 0.472932 0.409774 0.105263 0.145865               
#         print(csvreader)
        
#         if temp2[0] == 
#         line = f.readlines()
#         print(temp2[0])

# csvreader = csv.reader(file)
# rows = []
# for row in csvreader:
# #    print(row[3])
# Out:
# 0 0.462253 0.604530 0.746806 0.735192
# ['2240', '\n', ' ', '0', '.', '4', '178', '262']
# ['2240', '\n', ' ', '0', '.', '4', '324', '237']
# ['2240', '\n', ' ', '0', '.', '4', '259', '503']
# 0 0.441353 0.375940 0.201504 0.180451
# 0 0.594737 0.364662 0.276692 0.374436
# 0 0.401943 0.240283 0.227915 0.332155
# 0 0.509774 0.497744 0.350376 0.529323
# 0 0.415789 0.368421 0.183459 0.315789
# 0 0.403600 0.379210 0.146341 0.191638
#
# 0 0.480256 0.676539 0.155633 0.259001
# 0 0.644876 0.395760 0.148410 0.247350
# 0 0.584806 0.336572 0.342756 0.553004
# 0 0.624855 0.370499 0.135889 0.199768
# 0 0.578397 0.196283 0.191638 0.253194
# 0 0.439850 0.218797 0.204511 0.224060
# 0 0.579559 0.381533 0.282230 0.363531
# 0 0.469803 0.394309 0.339141 0.337979
# 0 0.496466 0.694346 0.130742 0.088339
# 0 0.367596 0.551103 0.587689 0.728223
# 0 0.487805 0.323461 0.333333 0.317073
# 0 0.518045 0.556391 0.171429 0.273684
# 0 0.474382 0.287986 0.203180 0.296820
# 0 0.537102 0.212898 0.233216 0.348057
# ...

# %%
with open('GORILLA LABEL 1.csv', 'r') as csv_file:
    reader = csv.reader(csv_file, delimiter = ',')   
    with open('new_names.csv', 'w') as new_file:
        csv_writer = csv.writer(new_file, delimiter='')
    #img = next(reader)[3]
   # print(img)
    for row in reader:
        csv_writer.writerow(line)
